# %%
2+3
9-8
4*6
8/4#will give the floating point output to give exact value 

5//2 #interger output we can get it (interger division)

#arithematic operation 

8+2*3

"""
BODMAS(rule) 
1)B{brackets-> ()[]{}}
2)O{orders->x^2 root(x)}
3)D{divide->÷}
4)M{multiply->x}
5)A{addition->+}
6)S{substrsct-> -}
"""
#powers
2 ** 3
#modulations reminder
10%3
#string -> combination of characters
'surya'
print('surya')
print('surya"s laptop')
print("surya's laptop")
print('surya\'s "laptop"')# use forward slash to skip the meaning of that single or double qote inside
print("c:\docs\navin")#prints avin in new line as "\n has meaning"
print(r"c:\docs\navin")# to print raw string we use "r"-> raw string dont convert it
# Out:
# surya
# surya"s laptop
# surya's laptop
# surya's "laptop"
# c:\docs
# avin
# c:\docs\navin

# %%
#variables in python
#variable is is container we can put our data
x=10
x+10
#output of the previous operation we can use "_" underscore to load it
# Out:
# 20

# %%
#output of the previous operation we can use "_" underscore to load it
_+5
# Out:
# 25

# %%
name='saisurya'
name+"rocks"
name[6]
name[-3]
name[0:2]
name[1:4]
name[1:]
name[:4]
name[3:10]#avoid errors
#strings in python are IMMUTABLE  that means we cannot change the values once they are assigned
#name[0]="r" not possible to change value
"my "+name[0:3]
len(name)# for length
# Out:
# 8

# %%
#LISTS
#it is simply an array of diffrent data types and square brakets[]
num=[12,24,4]
#all the operations performed through strings we can also perform here
name=["sai","surya","m"]
#for list of lists we can do 
mil=[num, name]
mil
#list is mutable ->we can change values
#pop up not coming we can press [CNTRL+ SPACE] for pop up suggesions 
num.insert(2,77)#insert(index value, number or value to be inserted)
num.append(34)#append will add value at end of list
num.remove(34)#to remove
num.pop(0)#specify index value in side pop
num.pop()#push pop ->no specify index value last element is removed [stack]
num
del num[0:]
num.extend([10,12,15,6])
num
min(num)
max(num)
sum(num)
num.sort()
num
num.sort(reverse=True)
num
num[::-1].sort()
num
# Out:
# [15, 12, 10, 6]

# %%
#tuples (tuple is immutable we cannot change values) and brakets-()
tup = (24,45,34,55,67)
#we cannot change the values in the values inside the tuples once assigned
#itterations speed is faster in tuples
tup[4]
#tup.insert(2,8) doent support all list operations as immutable so onlu count 
#Has only count and index
tup.index(45)
# Out:
# 1

# %%
#sets-> collections of unique elements curly brakets {}
set= {111,22,33,544,5,6}
set
#same as list mot maintain sequence and not support duplicate values
s={12,12,6,7,1,1}
s
# Out:
# {1, 6, 7, 12}

# %%
#python set path in windows and help
help()
# Out:
# Welcome to Python 3.8's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.8/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".

# %% [markdown]
# # """
# Welcome to Python 3.8's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.8/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> topics
#
# Here is a list of available topics.  Enter any topic name to get more help.
#
# ASSERTION           DELETION            LOOPING             SHIFTING
# ASSIGNMENT          DICTIONARIES        MAPPINGMETHODS      SLICINGS
# ATTRIBUTEMETHODS    DICTIONARYLITERALS  MAPPINGS            SPECIALATTRIBUTES
# ATTRIBUTES          DYNAMICFEATURES     METHODS             SPECIALIDENTIFIERS
# AUGMENTEDASSIGNMENT ELLIPSIS            MODULES             SPECIALMETHODS
# BASICMETHODS        EXCEPTIONS          NAMESPACES          STRINGMETHODS
# BINARY              EXECUTION           NONE                STRINGS
# BITWISE             EXPRESSIONS         NUMBERMETHODS       SUBSCRIPTS
# BOOLEAN             FLOAT               NUMBERS             TRACEBACKS
# CALLABLEMETHODS     FORMATTING          OBJECTS             TRUTHVALUE
# CALLS               FRAMEOBJECTS        OPERATORS           TUPLELITERALS
# CLASSES             FRAMES              PACKAGES            TUPLES
# CODEOBJECTS         FUNCTIONS           POWER               TYPEOBJECTS
# COMPARISON          IDENTIFIERS         PRECEDENCE          TYPES
# COMPLEX             IMPORTING           PRIVATENAMES        UNARY
# CONDITIONAL         INTEGER             RETURNING           UNICODE
# CONTEXTMANAGERS     LISTLITERALS        SCOPING
# CONVERSIONS         LISTS               SEQUENCEMETHODS
# DEBUGGING           LITERALS            SEQUENCES
#
# help> LISTS
# Mutable Sequence Types
# **********************
#
# The operations in the following table are defined on mutable sequence
# types. The "collections.abc.MutableSequence" ABC is provided to make
# it easier to correctly implement these operations on custom sequence
# types.
#
# In the table *s* is an instance of a mutable sequence type, *t* is any
# iterable object and *x* is an arbitrary object that meets any type and
# value restrictions imposed by *s* (for example, "bytearray" only
# accepts integers that meet the value restriction "0 <= x <= 255").
#
# +--------------------------------+----------------------------------+-----------------------+
# | Operation                      | Result                           | Notes                 |
# |================================|==================================|=======================|
# | "s[i] = x"                     | item *i* of *s* is replaced by   |                       |
# |                                | *x*                              |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s[i:j] = t"                   | slice of *s* from *i* to *j* is  |                       |
# |                                | replaced by the contents of the  |                       |
# |                                | iterable *t*                     |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "del s[i:j]"                   | same as "s[i:j] = []"            |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s[i:j:k] = t"                 | the elements of "s[i:j:k]" are   | (1)                   |
# |                                | replaced by those of *t*         |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "del s[i:j:k]"                 | removes the elements of          |                       |
# |                                | "s[i:j:k]" from the list         |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s.append(x)"                  | appends *x* to the end of the    |                       |
# |                                | sequence (same as                |                       |
# |                                | "s[len(s):len(s)] = [x]")        |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s.clear()"                    | removes all items from *s* (same | (5)                   |
# |                                | as "del s[:]")                   |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s.copy()"                     | creates a shallow copy of *s*    | (5)                   |
# |                                | (same as "s[:]")                 |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s.extend(t)" or "s += t"      | extends *s* with the contents of |                       |
# |                                | *t* (for the most part the same  |                       |
# |                                | as "s[len(s):len(s)] = t")       |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s *= n"                       | updates *s* with its contents    | (6)                   |
# |                                | repeated *n* times               |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s.insert(i, x)"               | inserts *x* into *s* at the      |                       |
# |                                | index given by *i* (same as      |                       |
# |                                | "s[i:i] = [x]")                  |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s.pop([i])"                   | retrieves the item at *i* and    | (2)                   |
# |                                | also removes it from *s*         |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s.remove(x)"                  | remove the first item from *s*   | (3)                   |
# |                                | where "s[i]" is equal to *x*     |                       |
# +--------------------------------+----------------------------------+-----------------------+
# | "s.reverse()"                  | reverses the items of *s* in     | (4)                   |
# |                                | place                            |                       |
# +--------------------------------+----------------------------------+-----------------------+
#
# Notes:
#
# 1. *t* must have the same length as the slice it is replacing.
#
# 2. The optional argument *i* defaults to "-1", so that by default
#    the last item is removed and returned.
#
# 3. "remove()" raises "ValueError" when *x* is not found in *s*.
#
# 4. The "reverse()" method modifies the sequence in place for
#    economy of space when reversing a large sequence.  To remind users
#    that it operates by side effect, it does not return the reversed
#    sequence.
#
# 5. "clear()" and "copy()" are included for consistency with the
#    interfaces of mutable containers that don’t support slicing
#    operations (such as "dict" and "set"). "copy()" is not part of the
#    "collections.abc.MutableSequence" ABC, but most concrete mutable
#    sequence classes provide it.
#
#    New in version 3.3: "clear()" and "copy()" methods.
#
# 6. The value *n* is an integer, or an object implementing
#    "__index__()".  Zero and negative values of *n* clear the sequence.
#    Items in the sequence are not copied; they are referenced multiple
#    times, as explained for "s * n" under Common Sequence Operations.
#
# Related help topics: LISTLITERALS"""

# %%
help('LISTS')
"""help()qiut"""

# %%
#more on variables

#memory consumption and allocation

num=5
#to get the address we use the function
print(id(num))

name="surya"
print(id(name))

a=10
b=a
a
b
print(id(a))
print(id(b))
#hence pointing to smae address so python is more memory efficient
#and adress is the box the value tagged adress same adress for all variables asisgned 
id(10)
#we have garbage collection .

#when the data is unused after allocation it will be there for use->garbage values

PI=3.14
PI=3.15
PI
type(PI)

# %%
#DATA TYPES IN PYTHON (type -> function for getting data type)
"""
none
numeric
list
tuple
set
string
range
Map (or Dicitinoary)
"""

#none-> havong variable but not assigned generally(null) but in python NONE

#Numeric-->[INT,FLOAT, COMPLEX, BOOL]
num=5
type(num)
num=5.6
type(num)
num=6+9j#a+ib
type(num)
a=5.6
b=int(a)
b
k=float(b)
k
c=complex(b,k)
c
#true or false come under boolean type
bool=b==k
type(bool)
#true -> 1 false-> 0
int(True)
int(False)
#list range set tuple comes under SEQUENCE
lst=[10,3,"t","t"]
type(lst)
s={10,3,"t","t"}
type(s)

#string

str="surya"
type(str)

#range ->fancy only in python
#when we itterate b/n values (0-9)-(9-6)
range(10)
list(range(10))
list(range(2,11,2))#strting,ending,repeat-after

#Dictionary / Map->huge data fetch fast
"""[List vs Dict]
for every value there we will have index but in dict we will have key
so by fetching key we can acces value for that rather indexing
EX:PHONES OF FRNDS 

ALL THE KEYS SHOULD BE UNIQUE AND VALUES CAN REPEAT
"""

d={'surya':'realme','bhanu':'moto'}
d.keys()
d.values()
d['surya']
d.get('bhanu')

# %%
#operators
"""
Arithematic Operators
Assignment Operators
Relational operators
Logical operators
unary operators
"""

# %%
#Arithematic Operators
x=2
y=3
x+y
x-y
print(x/y)
print('%.3f'%(x/y))#rounding of to the desired values of float 
x=2
x+=3
x*=3
x



#Assignment Operators->supports mutiple assignments
a,b=2,3
a
#unary operators->if you want to negate 
n=x
n=-n
n



#Relational operators
a<b
a>b
a==b
a<=b
a>=b
a!=b
id(a)


#Logical operators->[AND,OR,NOT]
a<8 and b<5

a<8 and b<2

a<8 or b<2

x=True
not x

# %%
#NUMBER SYSTEM AND CONVERSION IN PYTHON->[BINAY,DECIMAL,OCTAL,HEXADECIMAL]
bin(25)#[decimal(0-9) and binary(0-1) and octal(0-7) and hexadeci(0-15)]
oct(25)
hex(10)
0xf
31,52,65
0b110011010

# %%
# IDLE PREVIOUS COMMAND AND CLEAR SCREEN
#uparrow
#and in idle we cannot clear screen we can restrt

# %%
#PYTHON BITWISE OPERATORS
#DO WITH BINARY FORMAT--scientiic caluclations
"""
COMPLEMENT(~[TILDE])
AND(&)
OR(|)
XOR(^)
LEFTSHIFT(<<)
RIGHTSHIFT(>>)
"""
# COMPLEMENT(~[TILDE])
12#00001100
~12#11110011
#2's compliment->[1's compliment+1]
#in system we can store positive values -> if we want to store -ve values then convert to positive number 
#we can do that by 2's COMPLIMENT
#13 into binary 
print(bin(13))
print(bin(12))
#bitwise and and bitwise or
12&13
12|13  #  "|"pi
12^13
#left shift
10<<2#1010---->101000
10>>2#1010---->10.10

# %%
#important math functions in python
#sqrt square cube etc
#for sqrt
import math
x=math.sqrt(15)
x
#for flooring ->make integer & ceil
print(math.floor(2.9))

print(math.ceil(2.1))
3**2
print(math.pow(3,2))
print(math.pi)
math.e
#allies to call modules
import math as m
m.sqrt(25)

#only import a perticular funtion in module

from math import sqrt,pow
pow(4,5)

# %%
help('math')

# %%
# pycharm run debug python->now finished interactive console
# python file extension ".py"
"""
FOR COMMAND PROMPT RUNNING
cd Desktop
cd "folder_name"
python file_name.py
"""

# %%
#Getting input from users
"""
blunder is that whn we work with input it 
wil give always the input funtion takes as STRING

x=input("enter the 1 num:")
a=int(x)
y=input("enter the 2 num:")
b=int(y)
w=a+b
print(w)
z=x+y
print(z)
"""
#by using the short hand to reduce code lines
c=int(input())
d=int(input())
e=c+d
e

# %%
#Coding questions
#ch=input('enter the chracter:')[0]
#print(ch)#ch[0]
#EVALUATION[eval]
result=eval(input("enter the expression:"))
print(result)

# %%
#argv (argument values)->pass argumnets or values from the command line 
#sys for the passing values 

"""
import sys
#file_name.py[0]  values1[1]   value2[2]
x=int(sys.argv[1])
y=int(sys.argv[2])
print(c=x+y)
"""

# %%
#IF ELIF ELSE SATATEMNETS[Conditional statements]
# CPU ->CONTROL UNIT , ARITHEMATIC AND LOGIC UNIT, MEMORY UNIT, OUTPUT DEVICE, INPUT DEVICE
if True:#it is suit
    print('is right')#indentation->some specific spaces[1-TAB 4 spaces]
print("bye")

# %%
#even or odd
#if else and nested if else
x=2
r=x%2
if r==0:
    print("Even")
    if(x>5):
        print("great")
    else:
        print("not greate")
else:
    print("Odd")

# %%
#elif
x=1
if(x==1):
    print("one")
elif(x==2):
    print("two")
elif(x==3):
    print("three")
elif(x==4):
    print("four")
else:
    print("not in range")

# %%
#WHILE LOOP  AND FOR LOOP
#works on condition that is while loop 

i=5#initialization
while i>=1:#condition
    print("surya ",end="")#same line
    j=1
    while j<=4:
        print("rocks ",end="")
        j+=1
    
    i-=1#increment/decrement
    print()#for next line

# %%
#FOR LOOP
#works with the sequences
x=['navin', 63, 5.6]
for i in x:
    print(i)

for i in'navin', 63, 5.6:
    print(i)
    
for i in range(11,21,2):
    print(i)

# %%
#print only if not divisible by 5
for i in range(1,21):
    if (i%5!=0):
        print(i)

# %%
#BREAK , CONTINUE , PASS(keywords)


avg=5
x=int(input("enter candy:"))
i=1
while i<=x:
    if i>avg:
        print("out of stock")
        break
        
    print("candies")
    i=i+1
print("bye")


# for i in range(0,x):
#     if i>avg:
#         print("out of stock")
#         break
#     else:
#         print("candy")
# print("bye")

# %%
for i in range(1,101):
    if i%3==0 or i%5==0:
        continue
    print(i)

# %%
for i in range(1,101):
    if(i%2==0):
        pass #simply no code inside if just pass that in c->curly braces
    else:
        print(i)

# %%
x=int(input())
av=6
for i in range(1,x+1):
    if i>av:
        print("out of stock")
        break
        
    else:
        print("candy")

# %%
#printing pattrens in python
for i in range(4):     
    for j in range(4):
        print("# ", end="")
    print()

# %%
for i in range(4):
    for j in range(i+1):
        print("# ",end="")
    print()

# %%
for i in range(4):
    for j in range(4-i):
        print("# ",end="")
    print()

# %%
#OOP IN PYTHON
#PYTHON WORKS WITH [object oriented, functional, procedural oriented programming]
""" Object Oriented Programming - 03:15:49
23. Class and Object in Python - 03:22:29
24. _INIT_METHOD - 03:33:19
25. OPPs Concepts - 03:33:54
26. Types of Methods in Python - 03:55:30
27. Inner Class In Python - 04:06:46
28. Inheritance - 04:13:51
29. Operator Overloading - 04:36:21
30. Method Overloading and Method Overriding - 04:50:39
"""

# %%
#obejcts will have Attributes and Behaviour[store->variables, behaviour->methoda]
# functions in opps called as methods
#class object encapuslationn poluymorphism abstraction inheritence
#class is ->design blue print of objects
#objects are->entities or instance of class
#class and object
class computer:
    #attributes(variables) and behaviour(method)
    def config(self):#self is object which we are passing
        print("i5,16gb, 1tb")
com1 = computer()
com2 = computer()
com3 = computer()
# computer.config(com2)
# computer.config(com1)
com1.config()
com2.config()
# print(type(com1))
a=5
a.bit_length()

# %%
#Init method in python [__init__]-> constructor
#every obect has own value
#working with variables

#cpu and ram varialbes
class Computer:
    def __init__(self,cpu,ram):
        self.cpu = cpu
        self.ram = ram
        
        
    def config(self):
        print("Config is", self.cpu,self.ram,"GB ram")
        
com1=Computer('I5',16)
com2=Computer('Ryzen 5',8)
com1.config()
com2.config()

# %%
#1)Constructer ,2)self->pointer->refering to point and comparing objects in Python
class Computer:
    #heap memory in computer for object
    def __init__(self):
        self.name='surya'
        self.age=21
    def update(self):
        self.age=50
    def compare(self,other):#compare(who is calling, whom to compare)
        if self.age==other.age:
            return True
        else:
            return False
        
c1= Computer()
c2= Computer()
print(c1.name)
print(c2.name)
c1.name= "sai"

c2.update()
print(c1.name)
print(c2.age)
# print(id(c1))
# id(c2)
#SIZE OF CLASS WJO DECIDES AND ALLOCATES


# Size depends on the no of variables and size of variables the object has
#who allocates  the size of object is the CONSTRUCTOR->CALL __INIT__  INTERNALLY
#compare age
print(c1.age)

if c1.compare(c2):
    print("They are same")
else:
    print("they are different")

# %%
# TYPES OF VARIABLES IN PYTHON

#1) intsance variable
#2) class variable or Static variable
# VARIABLE IS OOPS is of 2 types 1)Insatnce Variable 2) Class(Static)Variable
class Car:
    #all the variables present inide class rather than the init are class varaibles
    wheels = 4
    def __init__(self):#all the varables in int are the instance variables
        self.mil = 10
        self.com = "BMW"
# we have 2 name space class and instance name space of variables
# in memory we have diffrent name space-> the area where you create & store object/variable
c12=Car()
c21=Car()
c12.mil=8
Car.wheels = 5
print(c12.com,c12.mil,c12.wheels)
print(c21.com,c21.mil)

# %%
# Types of methods
#1) intsance method
#2) class method 
#3) static method
class Student:
    
    school='AVR'
    
    def __init__(self,m1,m2,m3):
        
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3
    def avg(self):
        return (self.m1+self.m2+self.m3)/3
    
    
    
#     1)instance method
    def get_m1(self):#only get value->Accessors
        return self.m1
    def set_m1(self,value):#can set any value to the variable->mutator
        self.m1 = value
    #decorators
    
    
#     2)class method 
    @classmethod
    #as to create class method we use class variables use dictionoaries
    def info(cls):
        return cls.school
        
        
#     3)static method->nothing to do with class or instance or classs variable the use static method
    @staticmethod
    def infor():
        print("this is abc module")
    
s1=Student(55,55,55)
s2=Student(88,88,88)
s1.get_m1()
s2.set_m1(10)
s2.get_m1()
s2.avg()
Student.infor()

#avg method is types of instanec instance method->1)ACCESSOR METHODS 2)MUTATOR METHODS
# fetch the values of instance  variables->ACCESORS INSTANCE METHODS
#in order to modify the value of variables we use ->Mutator Methods

# %%
#Inner class in Python
# class 
# 1)variables
# 2)methods
class Stu:
    
    def __init__(self,name,roll):
        self.name = name
        self.roll = roll
        self.lap  = self.Laptop()
    def show(self):
        print(self.name, self.roll)
        self.lap.show()
    class Laptop:
        def __init__(self):
            self.brand = "lenovo"
            self.cpu = "i5"
        def show(self):
            print(self.brand, self.cpu)

s1=Stu('surya',3)
s1.show()

# %%
#Inheritence

#1)SINGLE LEVEL INHERITANCE 

class A:#SUPER CLASS/PARENT CLASS  #Grand father
    def feature1(self):
        print("1")
    def feature2(self):
        print("2")
        
class D:
    def feature10(self):
        print("10")
        
        
        
class B(A):#inheriting #SUBCLASS/CHILD CLASS #father
    def feature3(self):
        print("3")
    def feature4(self):
        print("4")
        
        
        
#2)MULTILEVEL INHERITANCE
class C(B):#child
    def feature5(self):
        print("5")


        
        
#3)MULTIPLE INHERITANCE 
class E(A,D):
    def feature20(self):
        print("20")
        

a1= A()

a1.feature1()
a1.feature2()

b1=B()
b1.feature1()
b1.feature2()
b1.feature3()
b1.feature4()   

c1=C()
c1.feature1()

e1=E()
e1.feature10()

# %%
#Constructor in INheritance Python
#METHOD RESOLUTION ORDER(MRO)

class A:#SUPER CLASS/PARENT CLASS  #Grand father
    def __init__(self):
        print("in a INIT")
    def feature1(self):
        print("1")
    def feature2(self):
        print("2")
        

class B:#(A):#inheriting #SUBCLASS/CHILD CLASS #father
    def __init__(self):
        super().__init__()
        print("in B init")
    def feature1(self):
        print("22")
    def feature3(self):
        
        print("3")
    def feature4(self):
        print("4")
# multiple inheritence we use MRO
class C(A,B):
    def __init__(self):
        super().__init__()
        print("in C")
    def feat(self):#to represent super class we use super method
        super().feature2()
a1= C()
a1.feature1()
a1.feat()

# %%
#Polymorphism in pyton
# poly-> Many  morphism->forms[MANY FORMS]
#use polymorphism at 1)loose couling 2)Depepndency injection 3)interface
# 1)DUCK TYPING
# 2)OPERRATOR OVERLOADING
# 3)METHOD OVERLOADING
# 4)METHOD OVER RIDING


# 1)DUCK TYPING----we have dynamic type
class Pycharm:
    def execute(self):
        print("i can run")
class Myeditor:
    def execute(self):
        print(" i can run")
        print("i can compile")
class Myowneditor:
    def execute(self):
        print("i can run")
        print("i can compile")
        print("i can spell check")
        print("i can do convention check")   
class Lap:
    def code(self,ide):
        ide.execute()
        
lap = Lap()
ide=Myowneditor()
lap.code(ide)

# %%
# 2)OPERRATOR OVERLOADING
#synthetic sugar
#MAGIC METHODS

a='5'
b='6'
print(a+b)
print(str.__add__(a,b))#this function is called behind the scene

# %%
#here we are overloaidng that is changing th addition parameter to re add operators
class Students:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2
    def __add__(self,other):
        m1= self.m1+other.m1
        m2= self.m1+other.m2
        s3 = Students(m1,m2)
        
        return s3
    def __gt__(self,other):
        r1 = self.m1+ self.m2
        r2 = other.m1+other.m2
        if r1>r2:
            return True
        else: 
            return False
    def __str__(self):
#         return self.m1,self.m2->returns the values in form of tuple
        return '{} {}'.format(self.m1,self.m2)#->returns in form of strings not in tuples type 
        
        
    
s1=Students(58,69)
s2=Students(69,65)
s3= s1+s2

#Prints the [MODULE CLASS OBJECT ADRESS]
#but after poly morphing the class it gives like this

print(s3.__str__())

# in order to efficiently print without the tuples like this we use
print(s3)
print(s1)
print(s2)
#for just printing 

print(s3.m1)

if s1>s2:
    print("s1 win")
else: 
    print("s2 wins")

# %%
# 3)METHOD OVERLOADING

#CONCEPT: having the same method name and but having diffrent arguments to pass
#is called method overloading
# EX: def averge(a,b): def average(a,b,c):
class addition:
    def __init__(self,m1,m2):
        self.m1=m1
        self.m2=m2
    def sum(self,a=None,b=None,c=None):#to implement METHOD OVERLOADING TRIK 
        s= 0
        if a!=None and b!=None and c!=None:
            s = a+b+c
        elif a!=None and b!=None:
            s=a+b
        else:
            s=a
        return s

    
s1=addition(10,10)

print(s1.sum(3,))

# %%
# 4)METHOD OVER RIDING->Dady's phone NOKIA 1100 till my phone till my phone MOTO COME
class A:
    def show(self):
        print("in a show")
class B(A):
    def show(self):#shows the subclass method
        print("in B show")
        
a1=B()
a1.show()

# %%
#ERROR Handling
# 1)COMPILE TIME ERROR (Syntactical error ex:if : (missing) wrong spell)
#2)LOGICAL Error(Syntax is correct evrything is executed but when user need 2+3=4 NOt correct out put )
#3)RUN TIME ERROR (logic and syntax alll crrct) but passing user values or argumrnts
# ex: wrong input 5/6coorct 10/5 corrct 6/0 error gives specific input error run time


# 3)Run time

a=5
b=0

try:#tryto executed if not return Exeption
    print("resource opend")
    print(a/b)
#     print("resource closed")
# if u have  any exception or run time error handle here by operations 


except Exception as e:#we can also show the error by having the Exception object method at the end 
    print("hey, you cannot divide a number by zero so error is:",e)
#     print("resource closed")
#if u need to close a file then we have 2 such cases so finally is used
# Finally block will be Executes if we get error as well as if we dont get error


finally:
    print("resource closed")
    
print()

print("Bye")

#when we open a fridge we need to close it DB connection after use clse Data base connection 
#if we open a file we again need to close that

# %%
#For targeting specific error we can do like this 


try:
    a=5
    b=int(input())
    print("resource open")
    print(a/b)
    k=int(input("enter a number:"))
    print(k)

except  ZeroDivisionError as e:
    print("Hey, you cannot divide a number  by Zero", e)

except ValueError as e:
    print("invalid Input")

except Exception as e:
    print("some thing went wrong....!")
    
finally:
    print("Resource closed")

# %%
#Multi Threading in python->multi task [ex:MS WORD]
#To import the thrading we use threading

from threading import *
from time import sleep
class Hello(Thread):
    def run(self):
        for i in range(5):
            print("HELLO")
            sleep(1)#1 -> emplies 1 second 
    

class Hi(Thread):
    def run(self):
        for i in range(5):
            print("HI")
            sleep(1)

t1=Hello()
t2=Hi()

#in system we will have SHEDULERS which always allocate tie for getting output 
#if we chNGE FOR LOOP TO 500 times each all the vales execute and may colloide 
#we can slow down we can shedule the tasks 
t1.start()
sleep(0.2)
t2.start()

t1.join()
t2.join()

print("Bye")

# %%
#File handling in python->we can use Relational data base [Mysql ,Oracle]

f= open('surya.txt','r')
print(f.readline(10), end="")
#print(f.readline())
#we have two lines 1 print we have new line, second-> also is file has new line 
f1=open('abc','w')
# f1.write("something")
# f1.write("people")
f1.write("Laptop")

# now we can append by using [A]
f1=open('abc','a')

f1.write("Mobile")

# %%
f= open('surya.txt','r')


f1=open('abc.txt','w')

for data in f:
    f1.write(data)

# %%
f= open('SaiSurya.PNG','rb')#for reading all binary vLUES WE USE[RB]
#gives all binary values
f1=open('Mypic.JPG','wb')

for i in f:
    f1.write(i)

# %%
#comments in python 
# single line comment and multiline comment
# """used  for documemtation"""

# %%
# IS PYTHON COMPILED OR INTERPRETED LANGUAGE
# python is both compiler and interpreted language
# compiler can be high to high as well

# SOURCE CODE ->COMPILER-> BYTE CODE->INTERPRTER->MACHINE LANGUAGE
#                               [VIRTUAL python machine]
#platform indepenency
#virtual machine will run bite code (PVM)
#REPL->
# CPYTHON
#ACTUALLY WE HAVE IMPLEMENTATIONS  1)CPYTHON clanguage 2)PyPy java language3)IRONPYTHION implement.net  4)JYTHON

# %%
#linear search using pyhton
pos = -1
def search(list,n):
    i=0
    while i<(len(list)):
        if list[i] == n:
            globals() ['pos'] = i
            return True
        i=i+1
    return False
        
list = [5,8,4,6,9,2]
n=9

if search(list,n):
    print("Found at",pos+1)
else:
    print("Not Found")

# %%
#using for loop

def search(list,n):
    i=0
    for i in range(0,len(list)):
        if list[i] == n:
            globals() ['pos'] = i
            return True
        i+=1
    return False
list = [5,8,4,6,9,2]
n = 9

if search(list,n):
    print('Found at', pos+1)
else:
    print('not found')

# %%
#Binary search we should have sorted value
#1)first specify lower bound and [index]
# 2)second upper bound the[index]
# 3)third find mid value
#we should do int division to get the mid value
#(0+5)//2  = element 8 mid value
#if search value is smaller then change upper bound & mid value becomes new upper bound
 


def search(list,n):
    l=0
    u=len(list)-1
    
    while l<=u:
        mid = (l+u)//2
        if list[mid]==n:
            globals() ['pos'] = mid
            return True
        else:
            if list[mid]<n:
                l= mid+1
            else:
                u = mid-1
list = [4,7,8,12,45,99]
n = 45

if search(list,n):
    print("Found at ", pos+1)
else:
    print("not found")
# Out:
# Found at  5

# %%
#Bubble Sort -> we use multiple ittrations and multiple swapping power consuming cpu
#[5,3,8,6,7,2]
#Swapping -> a=1= b=4 (t=a  b=a a=t)
#HERE OVERAL 5 ITTRATIONS 
a=1
b=4 
t=a  
a=b
b=t
print(a)
print(b)
# Out:
# 4
# 1

# %%
def sort(nums):
    for i in range(len(nums)-1,0,-1):
        for j in range(i):
            if nums[j]>nums[j+1]:
                temp = nums[j]
                nums[j]=nums[j+1]
                nums[j+1]=temp

nums =[5,3,8,6,7,2]
sort(nums)
print(nums)
# Out:
# [2, 3, 5, 6, 7, 8]

# %%
#SELECTION SORT ->find min  alue of all 
def sort(nums):
    for i in range(len(nums)):
        minpos=i
        for j in range(i,len(nums)):
            if nums[j]<nums[minpos]:
                minpos=j
        temp = nums[i]
        nums[i] = nums [minpos]
        nums[minpos]=temp
        print(nums)
        

nums =[5,3,8,6,7,2,8,10,2,1]
sort(nums)
print(nums)
# Out:
# [1, 3, 8, 6, 7, 2, 8, 10, 2, 5]
# [1, 2, 8, 6, 7, 3, 8, 10, 2, 5]
# [1, 2, 2, 6, 7, 3, 8, 10, 8, 5]
# [1, 2, 2, 3, 7, 6, 8, 10, 8, 5]
# [1, 2, 2, 3, 5, 6, 8, 10, 8, 7]
# [1, 2, 2, 3, 5, 6, 8, 10, 8, 7]
# [1, 2, 2, 3, 5, 6, 7, 10, 8, 8]
# [1, 2, 2, 3, 5, 6, 7, 8, 10, 8]
# [1, 2, 2, 3, 5, 6, 7, 8, 8, 10]
# [1, 2, 2, 3, 5, 6, 7, 8, 8, 10]
# [1, 2, 2, 3, 5, 6, 7, 8, 8, 10]

# %%
#my sql data base
# python database connectivity
